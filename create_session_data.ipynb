# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import pickle
import aux_functions as aux
importlib.reload(aux)
# Out:
# <module 'aux_functions' from 'e:\\vispred\\aux_functions.py'>

# %%
MONKEY = 'M08'
# MONKEY = 'M06'
# AREA = 'v4'

# %%
### Full cell list from a given monkey (every area, concatenated)

dicio_cell_list = {}
for area in ['ofc','te','teo','v4','vpa']:
    file_path = f'cell list {MONKEY}\\cell list {area}.txt' 
    dicio_cell_list[area] = aux.get_dataframe_cell_list(file_path)
    print(f'{area} data read and saved')
df_cell = pd.concat([item for item in dicio_cell_list.values()],axis=0)
df_cell
# Out:
# ofc data read and saved
# te data read and saved
# teo data read and saved
# v4 data read and saved
# vpa data read and saved
#       start            search             mapRF grid_coord  depth brain_area  \
# 0         1  m08cat072spk010b  m08det071spk010b      A+2+7    946        OFC
# 1         2  m08cat072spk012b  m08det071spk012b      A+2+7    966        OFC
# 2         3  m08cat075spk021b  m08det074spk021b      A+2+7    980        OFC
# 3         4  m08cat075spk029b  m08det074spk029b      A+2+7   1060        OFC
# 4         5  m08cat081spk012b  m08det080spk012b      A+0+7   1310        OFC
# ...     ...               ...               ...        ...    ...        ...
# 1176   1206  m08cat261spk089a  m08det260spk089a      B+4-4    805        VPA
# 1177   1207  m08cat261spk089z  m08det260spk089z      B+4-4    805        VPA
# 1178   1208  m08cat261spk091a  m08det260spk091a      B+4-4    820        VPA
# 1179   1209  m08cat261spk093a  m08det260spk093a      B+4-4    835        VPA
# ...

# %%
# Out:
#       start            search             mapRF grid_coord  depth brain_area  \
# 0         1  m08cat072spk010b  m08det071spk010b      A+2+7    946        OFC
# 2         3  m08cat075spk021b  m08det074spk021b      A+2+7    980        OFC
# 5         6  m08cat081spk065b  m08det080spk065b      A+2+7   1025        OFC
# 7         8  m08cat084spk003a  m08det083spk003a      A-1+7    898        OFC
# 8         9  m08cat084spk003c  m08det083spk003c      A-1+7    898        OFC
# ...     ...               ...               ...        ...    ...        ...
# 1808   2006  m06cat288spk091a  m06det287spk091a       +4-2    397        VPA
# 1812   2010  m06cat288spk093a  m06det287spk093a       +4-2    407        VPA
# 1813   2011  m06cat288spk093b  m06det287spk093b       +4-2    407        VPA
# 1816   2015  m06cat288spk095a  m06det287spk095a       +4-2    417        VPA
# 1817   2016  m06cat288spk095b  m06det287spk095b       +4-2    417        VPA
#
# ...

# %%
dicio_cell_list = {}
for MONKEY_ in ['M08','M06']:
    for area in ['ofc','te','teo','v4','vpa']:
        file_path = f'cell list {MONKEY_}\\cell list {area}.txt' 
        dicio_cell_list[(area,MONKEY_)] = aux.get_dataframe_cell_list(file_path)
        print(f'{area} data read and saved')
df_cell = pd.concat([item for item in dicio_cell_list.values()],axis=0)
df_cell
# Out:
# ofc data read and saved
# te data read and saved
# teo data read and saved
# v4 data read and saved
# vpa data read and saved
# ofc data read and saved
# te data read and saved
# teo data read and saved
# v4 data read and saved
# vpa data read and saved
#       start            search             mapRF grid_coord  depth brain_area  \
# 0         1  m08cat072spk010b  m08det071spk010b      A+2+7    946        OFC
# 1         2  m08cat072spk012b  m08det071spk012b      A+2+7    966        OFC
# 2         3  m08cat075spk021b  m08det074spk021b      A+2+7    980        OFC
# 3         4  m08cat075spk029b  m08det074spk029b      A+2+7   1060        OFC
# 4         5  m08cat081spk012b  m08det080spk012b      A+0+7   1310        OFC
# ...     ...               ...               ...        ...    ...        ...
# 1814   2013  m06cat288spk094a  m06det287spk094a       +4-2    567        VPA
# 1815   2014  m06cat288spk094z  m06det287spk094z       +4-2    567        VPA
# ...

# %%
df_cell = df_cell[(df_cell['RF_type']=='Focal Foveal') | ~(df_cell['RFin'].isna())]

# %%
len(df_cell['session'].unique())
# Out:
# 171

# %%
# OR just an area

# input(f'saving only {AREA} data. ok?')
# df_cell = aux.get_dataframe_cell_list(f'cell list {MONKEY}\\cell list {AREA}.txt')
# df_cell

# %%
df_v4tot = df_cell[df_cell['brain_area']=='V4']
df_v4fov = df_v4tot[df_v4tot['RF_type'] == 'Focal Foveal']
df_v4broadfov = df_v4tot[df_v4tot['RF_type'] == 'Broad Foveal']
df_v4perif = df_v4tot[df_v4tot['RF_type'] == 'Peripheral']


df_TEtot = df_cell[df_cell['brain_area']=='TE']
df_TEfov = df_TEtot[df_TEtot['RF_type'] == 'Focal Foveal']
df_TEbroadfov = df_TEtot[df_TEtot['RF_type'] == 'Broad Foveal']
df_TEperif = df_TEtot[df_TEtot['RF_type'] == 'Peripheral']

df_TEOtot = df_cell[df_cell['brain_area']=='TEO']
df_TEOfov = df_TEOtot[df_TEOtot['RF_type'] == 'Focal Foveal']
df_TEObroadfov = df_TEOtot[df_TEOtot['RF_type'] == 'Broad Foveal']
df_TEOperif = df_TEOtot[df_TEOtot['RF_type'] == 'Peripheral']

# %%
# df_v4 = df_cell[df_cell['brain_area']=='V4']
# df_fov = df_v4[df_v4['RF_type'] == 'Focal Foveal']
# df_nfov = df_v4[df_v4['RF_type'] != 'Focal Foveal']
# df_broadfov = df_v4[df_v4['RF_type'] == 'Broad Foveal']
# df_perif = df_v4[df_v4['RF_type'] == 'Peripheral']
# df_fov


# df_fov = df_cell[df_cell['RF_type'] == 'Focal Foveal']
# df_nfov = df_cell[df_cell['RF_type'] != 'Focal Foveal']
# df_fov
# Out:
#       start            search             mapRF grid_coord  depth brain_area  \
# 2         3  m08cat120spk033c  m08det119spk033c       +3+1    660         V4
# 3         4  m08cat120spk033z  m08det119spk033z       +3+1    660         V4
# 54       55  m08cat129spk098a  m08det128spk098a       +3-4   1110         V4
# 55       56  m08cat129spk098z  m08det128spk098z       +3-4   1110         V4
# 60       61  m08cat129spk100a  m08det128spk100a       +3-4   1130         V4
# ...     ...               ...               ...        ...    ...        ...
# 2262   2263  m08cat261spk127a  m08det260spk127a       +3-3    876         V4
# 2263   2264  m08cat261spk127b  m08det260spk127b       +3-3    876         V4
# 2264   2265  m08cat261spk127z  m08det260spk127z       +3-3    876         V4
# 2265   2266  m08cat261spk128a  m08det260spk128a       +3-3   1036         V4
# 2266   2267  m08cat261spk128z  m08det260spk128z       +3-3   1036         V4
#
# ...

# %%
# df_qtd_neurons = pd.DataFrame({'Non Foveal': df_nfov['session'].value_counts(), 'Foveal': df_fov['session'].value_counts(),'Total':df_v4['session'].value_counts()}).fillna(0).sort_values('Foveal',ascending=False)
# df_qtd_neurons = pd.DataFrame({'Broad Foveal': df_broadfov['session'].value_counts(), 'Foveal': df_fov['session'].value_counts(),'Peripheral':df_perif['session'].value_counts(),'Total':df_v4['session'].value_counts()}).fillna(0).sort_values('Foveal',ascending=False)
# df_qtd_neurons['Pct Foveal'] = 100 * df_qtd_neurons['Foveal'] / df_qtd_neurons['Total']
# df_qtd_neurons[df_qtd_neurons['Foveal']>=4]
# df_qtd_neurons[df_qtd_neurons['Foveal']>=4]

# %%
# df_qtd_neurons_TE = pd.DataFrame({'Broad Foveal': df_TEbroadfov['session'].value_counts(), 'Foveal': df_TEfov['session'].value_counts(),'Peripheral':df_TEperif['session'].value_counts(),'Total':df_TEtot['session'].value_counts()}).fillna(0).sort_values('Foveal',ascending=False)
# df_qtd_neurons_TEO = pd.DataFrame({'Broad Foveal': df_TEObroadfov['session'].value_counts(), 'Foveal': df_TEOfov['session'].value_counts(),'Peripheral':df_TEOperif['session'].value_counts(),'Total':df_TEOtot['session'].value_counts()}).fillna(0).sort_values('Foveal',ascending=False)
# df_qtd_neurons_TE

# %%
df_qtd_neurons = pd.DataFrame({'V4 Broad Foveal': df_v4broadfov['session'].value_counts(), 'V4 Foveal': df_v4fov['session'].value_counts(),'V4 Peripheral':df_v4perif['session'].value_counts(),'V4 Total':df_v4tot['session'].value_counts(),
                               'TE Broad Foveal': df_TEbroadfov['session'].value_counts(), 'TE Foveal': df_TEfov['session'].value_counts(),'TE Peripheral':df_TEperif['session'].value_counts(),'TE Total':df_TEtot['session'].value_counts(),
                               'TEO Broad Foveal': df_TEObroadfov['session'].value_counts(), 'TEO Foveal': df_TEOfov['session'].value_counts(),'TEO Peripheral':df_TEOperif['session'].value_counts(),'TEO Total':df_TEOtot['session'].value_counts(),
                               }).fillna(0).sort_values('V4 Foveal',ascending=False)
df_qtd_neurons['IT Total'] = df_qtd_neurons['TE Total']+df_qtd_neurons['TEO Total']
df_qtd_neurons
# Out:
#            V4 Broad Foveal  V4 Foveal  V4 Peripheral  V4 Total  \
# m08cat255              0.0       87.0            0.0      87.0
# m08cat252              0.0       66.0            0.0      66.0
# m06cat279              0.0       65.0            0.0      65.0
# m08cat261              0.0       60.0            0.0      60.0
# m08cat258              0.0       57.0            0.0      57.0
# ...                    ...        ...            ...       ...
# m08cat037              0.0        0.0            0.0       0.0
# m08cat034              0.0        0.0            0.0       0.0
# m08cat030              0.0        0.0            0.0       0.0
# m08cat027              0.0        0.0            0.0       0.0
# m06cat003              0.0        0.0            0.0       0.0
#
#            TE Broad Foveal  TE Foveal  TE Peripheral  TE Total  \
# m08cat255              8.0       87.0            0.0      95.0
# m08cat252             22.0       39.0            1.0      62.0
# ...

# %%
df_qtd_neurons[df_qtd_neurons['TEO Total']>0].sort_values('TE Total')
# Out:
#            V4 Broad Foveal  V4 Foveal  V4 Peripheral  V4 Total  \
# m08cat129              0.0       48.0            0.0      48.0
# m06cat123              0.0        0.0           22.0      22.0
# m06cat105              0.0        0.0            0.0       0.0
# m06cat102              0.0        0.0            0.0       0.0
# m06cat099              0.0        0.0            0.0       0.0
# ...                    ...        ...            ...       ...
# m08cat135              0.0        0.0           43.0      43.0
# m08cat144              0.0        0.0           16.0      16.0
# m08cat114              0.0        0.0            0.0       0.0
# m08cat159              0.0        1.0            5.0       6.0
# m06cat003              0.0        0.0            0.0       0.0
#
#            TE Broad Foveal  TE Foveal  TE Peripheral  TE Total  \
# m08cat129              0.0        0.0            0.0       0.0
# m06cat123              0.0        0.0            0.0       0.0
# ...

# %%
print(len(df_qtd_neurons[(df_qtd_neurons['IT Total']>0) & (df_qtd_neurons['V4 Total']>0)].index))
print(len(df_qtd_neurons[(df_qtd_neurons['TE Total']>0) & (df_qtd_neurons['V4 Total']>0)].index))
print(len(df_qtd_neurons[(df_qtd_neurons['TEO Total']>0) & (df_qtd_neurons['V4 Total']>0)].index))
# Out:
# 53
# 20
# 33

# %%
# df_qtd_neurons[(df_qtd_neurons['TE Total']>0) & (df_qtd_neurons['V4 Total']>0)][['V4 Peripheral','TE Foveal']]
print(len(df_qtd_neurons[(df_qtd_neurons['TE Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','TE Foveal']].index))
df_qtd_neurons[(df_qtd_neurons['TE Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','TE Foveal']]
# Out:
# 9
#            V4 Peripheral  TE Foveal
# m08cat204            8.0       38.0
# m08cat195           15.0       69.0
# m08cat201           14.0       59.0
# m08cat198           23.0       31.0
# m08cat210            5.0       18.0
# m08cat207            6.0       35.0
# m08cat192           11.0       66.0
# m08cat189           10.0       70.0
# m08cat186           31.0       35.0

# %%
# df_qtd_neurons[(df_qtd_neurons['TEO Total']>0) & (df_qtd_neurons['V4 Total']>0)][['V4 Peripheral','TEO Foveal']]
print(len(df_qtd_neurons[(df_qtd_neurons['TEO Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','TEO Foveal']].index))
df_qtd_neurons[(df_qtd_neurons['TEO Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','TEO Foveal']]
# Out:
# 9
#            V4 Peripheral  TEO Foveal
# m06cat126           16.0         7.0
# m06cat147           20.0         5.0
# m06cat135           14.0         8.0
# m06cat144           22.0        13.0
# m06cat138           20.0         6.0
# m06cat150           27.0        16.0
# m06cat123           22.0        11.0
# m06cat141           27.0         9.0
# m06cat153           24.0         7.0

# %%
# print(len(df_qtd_neurons[(df_qtd_neurons['V4 Foveal']>0) & (df_qtd_neurons['V4 Peripheral']>0)][['V4 Peripheral','V4 Foveal']].index))
# df_qtd_neurons[(df_qtd_neurons['V4 Foveal']>0) & (df_qtd_neurons['V4 Peripheral']>0)][['V4 Peripheral','V4 Foveal']]

# %%
print(len(df_qtd_neurons[(df_qtd_neurons['V4 Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','V4 Foveal']].index))
df_qtd_neurons[(df_qtd_neurons['V4 Foveal']>3) & (df_qtd_neurons['V4 Peripheral']>3)][['V4 Peripheral','V4 Foveal']]
# df_qtd_neurons[(df_qtd_neurons['V4 Foveal']>0) & (df_qtd_neurons['V4 Peripheral']>0)][['V4 Peripheral','V4 Foveal']]
# Out:
# 24
#            V4 Peripheral  V4 Foveal
# m06cat231           13.0       33.0
# m06cat177           17.0       31.0
# m06cat261            7.0       29.0
# m06cat180            7.0       29.0
# m06cat255            7.0       27.0
# m08cat240            4.0       24.0
# m06cat264           16.0       24.0
# m06cat249            9.0       22.0
# m06cat234           12.0       20.0
# m08cat204            8.0       16.0
# m08cat156            7.0       15.0
# m06cat126           16.0       15.0
# m08cat246            6.0       12.0
# m08cat195           15.0       11.0
# m06cat246           22.0       10.0
# m06cat240            7.0        9.0
# m06cat147           20.0        8.0
# m06cat132           18.0        7.0
# m06cat135           14.0        7.0
# m08cat201           14.0        6.0
# m08cat234           15.0        5.0
# m06cat273            4.0        4.0
# m08cat198           23.0        4.0
# m06cat243           23.0        4.0

# %%
# SESSION = 'm08cat255'
# SESSION = 'm08cat252'
# SESSION = 'm08cat261'
# SESSION = 'm08cat129'
# SESSION = 'm08cat156'

# SESSION = "m06cat279"
# SESSION = "m06cat210"
# SESSION = "m06cat192"

# %%
# input(f'saving only {SESSION} data and ONLY FOVEAL. ok?')
# df_session = df_fov[df_fov['session']==SESSION]
# df_session

# %%
df_session = df_cell[df_cell['session']==SESSION]
print(df_session['brain_area'].value_counts())
df_session.index = pd.Index(range(len(df_session.index)))
df_session
# Out:
# V4     87
# VPA    52
# Name: brain_area, dtype: int64
#      start            search             mapRF grid_coord  depth brain_area  \
# 0     1398  m06cat192spk097a  m06det191spk097a       +3-7    241         V4
# 1     1399  m06cat192spk097b  m06det191spk097b       +3-7    241         V4
# 2     1400  m06cat192spk097z  m06det191spk097z       +3-7    241         V4
# 3     1401  m06cat192spk098a  m06det191spk098a       +3-7    401         V4
# 4     1402  m06cat192spk098b  m06det191spk098b       +3-7    401         V4
# ..     ...               ...               ...        ...    ...        ...
# 134    190  m06cat192spk093a  m06det191spk093a       +3+0    391        VPA
# 135    191  m06cat192spk093b  m06det191spk093b       +3+0    391        VPA
# 136    193  m06cat192spk095a  m06det191spk095a       +3+0    401        VPA
# 137    194  m06cat192spk095z  m06det191spk095z       +3+0    401        VPA
# 138    195  m06cat192spk096a  m06det191spk096a       +3+0    561        VPA
#
# ...

# %%
with open(f"session_data\\{SESSION}.pkl", "wb") as file:
    pickle.dump(df_session, file)

# %%
# df_session = df_session[df_session['brain_area']=='V4']

# %%
# path_destiny = f'dados\\{MONKEY}_neurons\\neurons sorted'
# list_neuron_ids = df_session['search']
# list_prefered_cat = df_session['prefer']
# list_brain_area = df_session['brain_area']
# list_RF_type = df_session['RF_type']

# # OBS: spike times here stop in the END OF THE FIRST FIX!!! We can alter later for posterior analysis.
# df_trials = aux.get_df_trials(list_neuron_ids, path_destiny, list(list_prefered_cat), list(list_brain_area), list(list_RF_type), firings_cue_and_array=True)
# df_trials

# %%
# sacc_start	start_first_fix	end_first_fix
# plt.hist(df_trials['start_first_fix'] - df_trials['sacc_start'], bins=np.arange(-0.05,0.1,0.01),cumulative=False,density=True)
# plt.hist(df_trials['end_first_fix']-df_trials['start_first_fix'] , bins=np.arange(-0.2,0.5,0.01),cumulative=False,density=True)
